# %%
import torch

# %%
a = torch.rand((128, 128, 3))
a.shape
# Out:
# torch.Size([128, 128, 3])

# %%
torch.sum(a, dim=(0,1))
# Out:
# tensor([8186.1074, 8185.8608, 8198.3857])

# %%
torch.nn.functional.normalize(torch.tensor([1.0,2.0,3.0]), dim=0, p=0)
# Out:
# tensor([0.3333, 0.6667, 1.0000])

# %%
import torchvision

# %%
image = torchvision.io.read_image(r"C:\Users\dranh\Desktop\Screenshot 2022-08-25 185238.jpg") / 255
image.shape
# Out:
# torch.Size([3, 345, 532])

# %%
import matplotlib.pyplot as plt
plt.imshow(torch.permute(image, (1,2,0)))

# %%
L = torch.nn.functional.normalize(torch.sum(image, dim=(1,2)), dim=0, p=2)
print(L)
illuminant_image = L.repeat((10,10,1))
plt.imshow(illuminant_image)
# Out:
# tensor([0.3064, 0.7968, 0.5208])
